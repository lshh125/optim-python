# %%
# %load_ext autoreload
import numpy as np
import matplotlib.pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
loss_fun = lambda x: x ** 2
grad_fun = lambda x: 2 * x

# %%
# %autoreload
from optim.gradient import gradient_descent
rec = gradient_descent(loss_fun, grad_fun, np.array([1.5]), lr = 0.2, max_iter=10)
# Out:
# 0 [1.5] [2.25]
# 1 [0.9] [0.81]
# 2 [0.54] [0.2916]
# 3 [0.324] [0.104976]
# 4 [0.1944] [0.03779136]
# 5 [0.11664] [0.01360489]
# 6 [0.069984] [0.00489776]
# 7 [0.0419904] [0.00176319]
# 8 [0.02519424] [0.00063475]
# 9 [0.01511654] [0.00022851]
# 10 [0.00906993] [8.22635649e-05]

# %%
x = np.linspace(-2, 2, 1000)
plt.plot(x, loss_fun(x))
plt.plot(rec, loss_fun(rec))

# %%
loss_fun = lambda x: x ** 4
grad_fun = lambda x: 4 * x ** 3

# %%
# %autoreload
from optim.gradient import gradient_descent
rec = gradient_descent(loss_fun, grad_fun, np.array([2]), lr = 0.02, max_iter=10)
# Out:
# 0 [2] [16]
# 1 [1.36] [3.42102016]
# 2 [1.15876352] [1.80293163]
# 3 [1.03429073] [1.1443807]
# 4 [0.94577552] [0.80011476]
# 5 [0.87809648] [0.59452339]
# 6 [0.82393174] [0.46085566]
# 7 [0.77918476] [0.36860549]
# 8 [0.74133952] [0.30204288]
# 9 [0.70874523] [0.25232519]
# 10 [0.68026389] [0.21414586]

# %%
x = numpy.linspace(-2, 2, 1000)
plt.plot(x, loss_fun(x))
plt.plot(rec, loss_fun(rec))

# %%
loss_fun = lambda x: x ** 3 + 2 * (4 * x + 1) ** 2
grad_fun = lambda x: 3 * x ** 2 + 4 * (4 * x + 1)


# %autoreload
from optim.gradient import gradient_descent
rec = gradient_descent(loss_fun, grad_fun, np.array([2]), lr = 0.02, max_iter=10)

x = numpy.linspace(-2, 2, 1000)
plt.plot(x, loss_fun(x))
plt.plot(rec, loss_fun(rec))
# Out:
# 0 [2] [170]
# 1 [1.04] [54.376064]
# 2 [0.562304] [21.29260176]
# 3 [0.28339557] [9.12710715]
# 4 [0.10789021] [4.09998867]
# 5 [-0.00733308] [1.88439114]
# 6 [-0.08498972] [0.87069467]
# 7 [-0.1382264] [0.39714575]
# 8 [-0.17514035] [0.17395468]
# 9 [-0.20093588] [0.06892037]
# 10 [-0.21905892] [0.02012329]
